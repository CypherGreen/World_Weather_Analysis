# %%
#Import Dependancies
from citipy import citipy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0        
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | saskylakh
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | oksfjord
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | dera din panah
# City not found. Skipping...
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | taoudenni
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | makakilo city
# Processing Record 16 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | back mountain
# Processing Record 19 of Set 1 | tiznit
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | hambantota
# Processing Record 23 of Set 1 | vardo
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | leningradskiy
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | silver city
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | santa margherita ligure
# Processing Record 31 of Set 1 | grand-santi
# Processing Record 32 of Set 1 | gamba
# Processing Record 33 of Set 1 | maragogi
# Processing Record 34 of Set 1 | qazvin
# Processing Record 35 of Set 1 | kavaratti
# Processing Record 36 of Set 1 | bengkulu
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | bathsheba
# Processing Record 43 of Set 1 | guarapari
# Processing Record 44 of Set 1 | san patricio
# Processing Record 45 of Set 1 | yar-sale
# Processing Record 46 of Set 1 | hualmay
# Processing Record 47 of Set 1 | pacific grove
# Processing Record 48 of Set 1 | kudahuvadhoo
# Processing Record 49 of Set 1 | camana
# Processing Record 50 of Set 1 | shakawe
# Processing Record 1 of Set 2 | bogatoye
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | mabaruma
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | kieta
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | kloulklubed
# Processing Record 9 of Set 2 | saint joseph
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | beringovskiy
# Processing Record 12 of Set 2 | kampong thum
# Processing Record 13 of Set 2 | great falls
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | ust-ilimsk
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | wenling
# Processing Record 20 of Set 2 | acapulco
# Processing Record 21 of Set 2 | champerico
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | bumba
# Processing Record 24 of Set 2 | ust-nera
# Processing Record 25 of Set 2 | atar
# Processing Record 26 of Set 2 | tongling
# Processing Record 27 of Set 2 | bonavista
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | cherskiy
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | sawtell
# Processing Record 34 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 2 | barmer
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | nizhnevartovsk
# Processing Record 39 of Set 2 | deming
# Processing Record 40 of Set 2 | bemidji
# Processing Record 41 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 2 | omboue
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | tautira
# Processing Record 45 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 2 | topeka
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | calbuco
# Processing Record 49 of Set 2 | tramore
# Processing Record 50 of Set 2 | praia
# Processing Record 1 of Set 3 | monclova
# Processing Record 2 of Set 3 | khandyga
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | zeya
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | trairi
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | nyaunglebin
# Processing Record 13 of Set 3 | siddharthanagar
# Processing Record 14 of Set 3 | aluksne
# Processing Record 15 of Set 3 | itarema
# Processing Record 16 of Set 3 | geraldton
# Processing Record 17 of Set 3 | sao jose do belmonte
# Processing Record 18 of Set 3 | samarai
# Processing Record 19 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 3 | sesheke
# Processing Record 21 of Set 3 | solnechnyy
# Processing Record 22 of Set 3 | hobyo
# Processing Record 23 of Set 3 | jining
# Processing Record 24 of Set 3 | amga
# Processing Record 25 of Set 3 | rundu
# Processing Record 26 of Set 3 | hobart
# Processing Record 27 of Set 3 | terme
# Processing Record 28 of Set 3 | soloneshnoye
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | adrar
# Processing Record 32 of Set 3 | flinders
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | primorsko
# Processing Record 35 of Set 3 | baena
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | kibala
# Processing Record 42 of Set 3 | sinnamary
# Processing Record 43 of Set 3 | kundla
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | fairbanks
# Processing Record 46 of Set 3 | lagoa
# Processing Record 47 of Set 3 | luwuk
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | yumen
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | jalu
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | roma
# Processing Record 4 of Set 4 | kuryk
# Processing Record 5 of Set 4 | knysna
# Processing Record 6 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 7 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 8 of Set 4 | flin flon
# Processing Record 9 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 4 | muscat
# Processing Record 11 of Set 4 | konice
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | sao raimundo nonato
# Processing Record 14 of Set 4 | paamiut
# Processing Record 15 of Set 4 | opuwo
# Processing Record 16 of Set 4 | port elizabeth
# Processing Record 17 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 4 | morehead
# Processing Record 19 of Set 4 | fortuna
# Processing Record 20 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 4 | pisco
# Processing Record 22 of Set 4 | athabasca
# Processing Record 23 of Set 4 | ballina
# Processing Record 24 of Set 4 | uyovu
# Processing Record 25 of Set 4 | danane
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | clyde river
# Processing Record 28 of Set 4 | corn island
# Processing Record 29 of Set 4 | broome
# Processing Record 30 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 4 | mayor pablo lagerenza
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | sambava
# Processing Record 34 of Set 4 | hami
# Processing Record 35 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | san luis rio colorado
# Processing Record 37 of Set 4 | abu zabad
# Processing Record 38 of Set 4 | tskneti
# Processing Record 39 of Set 4 | bereda
# Processing Record 40 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 4 | antigonish
# Processing Record 42 of Set 4 | olavarria
# Processing Record 43 of Set 4 | sergeyevka
# Processing Record 44 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 4 | othonoi
# City not found. Skipping...
# Processing Record 47 of Set 4 | kahului
# Processing Record 48 of Set 4 | berlevag
# Processing Record 49 of Set 4 | guicheng
# City not found. Skipping...
# Processing Record 50 of Set 4 | teguldet
# Processing Record 1 of Set 5 | curup
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | bria
# Processing Record 4 of Set 5 | ziguinchor
# Processing Record 5 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 6 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | itamaraca
# Processing Record 9 of Set 5 | cam ranh
# Processing Record 10 of Set 5 | katsuura
# Processing Record 11 of Set 5 | kondinskoye
# Processing Record 12 of Set 5 | port hawkesbury
# Processing Record 13 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 14 of Set 5 | ulaanbaatar
# Processing Record 15 of Set 5 | sitio novo do tocantins
# Processing Record 16 of Set 5 | bonthe
# Processing Record 17 of Set 5 | tessalit
# Processing Record 18 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 5 | masunga
# Processing Record 20 of Set 5 | uporovo
# Processing Record 21 of Set 5 | hamilton
# Processing Record 22 of Set 5 | bosaso
# Processing Record 23 of Set 5 | sokolka
# Processing Record 24 of Set 5 | aripuana
# Processing Record 25 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 5 | laguna
# Processing Record 27 of Set 5 | liminangcong
# City not found. Skipping...
# Processing Record 28 of Set 5 | watertown
# Processing Record 29 of Set 5 | ulaangom
# Processing Record 30 of Set 5 | novo cruzeiro
# Processing Record 31 of Set 5 | arlit
# Processing Record 32 of Set 5 | bubaque
# Processing Record 33 of Set 5 | tarrafal
# Processing Record 34 of Set 5 | zhezkazgan
# Processing Record 35 of Set 5 | dingle
# Processing Record 36 of Set 5 | grand gaube
# Processing Record 37 of Set 5 | vila franca do campo
# Processing Record 38 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 5 | ponta do sol
# Processing Record 40 of Set 5 | biak
# Processing Record 41 of Set 5 | bethlehem
# Processing Record 42 of Set 5 | tura
# Processing Record 43 of Set 5 | rovaniemi
# Processing Record 44 of Set 5 | serednye vodyane
# Processing Record 45 of Set 5 | nouadhibou
# Processing Record 46 of Set 5 | provideniya
# Processing Record 47 of Set 5 | batemans bay
# Processing Record 48 of Set 5 | marawi
# Processing Record 49 of Set 5 | ola
# Processing Record 50 of Set 5 | khokholskiy
# City not found. Skipping...
# Processing Record 1 of Set 6 | sioux lookout
# Processing Record 2 of Set 6 | road town
# Processing Record 3 of Set 6 | dunedin
# Processing Record 4 of Set 6 | bashtanka
# Processing Record 5 of Set 6 | sfantu gheorghe
# Processing Record 6 of Set 6 | barrow
# Processing Record 7 of Set 6 | varhaug
# Processing Record 8 of Set 6 | radeberg
# Processing Record 9 of Set 6 | hasaki
# Processing Record 10 of Set 6 | pangnirtung
# Processing Record 11 of Set 6 | faanui
# Processing Record 12 of Set 6 | avera
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | college
# Processing Record 15 of Set 6 | bredasdorp
# Processing Record 16 of Set 6 | chumikan
# Processing Record 17 of Set 6 | souillac
# Processing Record 18 of Set 6 | marsabit
# Processing Record 19 of Set 6 | roros
# Processing Record 20 of Set 6 | tromso
# Processing Record 21 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 6 | lubumbashi
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | rio grande
# Processing Record 25 of Set 6 | orbetello
# Processing Record 26 of Set 6 | summerville
# Processing Record 27 of Set 6 | palmas bellas
# Processing Record 28 of Set 6 | malakal
# Processing Record 29 of Set 6 | mirzapur
# Processing Record 30 of Set 6 | arraial do cabo
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | qaanaaq
# Processing Record 33 of Set 6 | itaueira
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | shingu
# Processing Record 36 of Set 6 | pumiao
# Processing Record 37 of Set 6 | valdivia
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | boa vista
# Processing Record 40 of Set 6 | imbituba
# Processing Record 41 of Set 6 | bentiu
# Processing Record 42 of Set 6 | kalmunai
# Processing Record 43 of Set 6 | akdepe
# Processing Record 44 of Set 6 | lata
# Processing Record 45 of Set 6 | rawson
# Processing Record 46 of Set 6 | longyearbyen
# Processing Record 47 of Set 6 | storforshei
# Processing Record 48 of Set 6 | thompson
# Processing Record 49 of Set 6 | zhigansk
# Processing Record 50 of Set 6 | ancud
# Processing Record 1 of Set 7 | chara
# Processing Record 2 of Set 7 | marsa matruh
# Processing Record 3 of Set 7 | namikupa
# Processing Record 4 of Set 7 | pierre
# Processing Record 5 of Set 7 | doka
# Processing Record 6 of Set 7 | norman wells
# Processing Record 7 of Set 7 | pochutla
# Processing Record 8 of Set 7 | homestead
# Processing Record 9 of Set 7 | itoigawa
# Processing Record 10 of Set 7 | port lincoln
# Processing Record 11 of Set 7 | pitimbu
# Processing Record 12 of Set 7 | muros
# Processing Record 13 of Set 7 | nanortalik
# Processing Record 14 of Set 7 | vao
# Processing Record 15 of Set 7 | comodoro rivadavia
# Processing Record 16 of Set 7 | jinchang
# Processing Record 17 of Set 7 | adamas
# Processing Record 18 of Set 7 | mecca
# Processing Record 19 of Set 7 | cockburn town
# Processing Record 20 of Set 7 | namatanai
# Processing Record 21 of Set 7 | asau
# Processing Record 22 of Set 7 | lotofaga
# Processing Record 23 of Set 7 | mahajanga
# Processing Record 24 of Set 7 | touros
# Processing Record 25 of Set 7 | kabalo
# Processing Record 26 of Set 7 | danville
# Processing Record 27 of Set 7 | chuy
# Processing Record 28 of Set 7 | kamenka
# Processing Record 29 of Set 7 | dikson
# Processing Record 30 of Set 7 | egvekinot
# Processing Record 31 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 32 of Set 7 | tigil
# Processing Record 33 of Set 7 | geilo
# Processing Record 34 of Set 7 | vung tau
# Processing Record 35 of Set 7 | nabire
# Processing Record 36 of Set 7 | klaksvik
# Processing Record 37 of Set 7 | thunder bay
# Processing Record 38 of Set 7 | itoman
# Processing Record 39 of Set 7 | bambanglipuro
# Processing Record 40 of Set 7 | tomatlan
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | hofn
# Processing Record 43 of Set 7 | victoria
# Processing Record 44 of Set 7 | colquechaca
# Processing Record 45 of Set 7 | honiara
# Processing Record 46 of Set 7 | pishin
# Processing Record 47 of Set 7 | saryg-sep
# Processing Record 48 of Set 7 | gravdal
# Processing Record 49 of Set 7 | kulhudhuffushi
# Processing Record 50 of Set 7 | sarai
# Processing Record 1 of Set 8 | vermillion
# Processing Record 2 of Set 8 | kokstad
# Processing Record 3 of Set 8 | erzin
# Processing Record 4 of Set 8 | marrakesh
# Processing Record 5 of Set 8 | mogadouro
# Processing Record 6 of Set 8 | korla
# Processing Record 7 of Set 8 | namibe
# Processing Record 8 of Set 8 | sistranda
# Processing Record 9 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 8 | gazanjyk
# Processing Record 11 of Set 8 | imisli
# City not found. Skipping...
# Processing Record 12 of Set 8 | rio gallegos
# Processing Record 13 of Set 8 | kishi
# Processing Record 14 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 15 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 8 | kanniyakumari
# Processing Record 17 of Set 8 | hlukhiv
# Processing Record 18 of Set 8 | kalach-na-donu
# Processing Record 19 of Set 8 | belomorsk
# Processing Record 20 of Set 8 | sao felix do xingu
# Processing Record 21 of Set 8 | ambulu
# Processing Record 22 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 8 | wangdiphodrang
# City not found. Skipping...
# Processing Record 24 of Set 8 | dakar
# Processing Record 25 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 8 | talaya
# Processing Record 27 of Set 8 | semnan
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | los llanos de aridane
# Processing Record 30 of Set 8 | bairiki
# Processing Record 31 of Set 8 | westport
# Processing Record 32 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 8 | las cruces
# Processing Record 34 of Set 8 | port hedland
# Processing Record 35 of Set 8 | praia da vitoria
# Processing Record 36 of Set 8 | mpongwe
# Processing Record 37 of Set 8 | cap malheureux
# Processing Record 38 of Set 8 | cidreira
# Processing Record 39 of Set 8 | belaya gora
# Processing Record 40 of Set 8 | talbahat
# Processing Record 41 of Set 8 | oranjestad
# Processing Record 42 of Set 8 | silopi
# Processing Record 43 of Set 8 | joshimath
# Processing Record 44 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 8 | havre-saint-pierre
# Processing Record 46 of Set 8 | okhotsk
# Processing Record 47 of Set 8 | jutai
# Processing Record 48 of Set 8 | iqaluit
# Processing Record 49 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 8 | coquimbo
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | camacha
# Processing Record 3 of Set 9 | cochabamba
# Processing Record 4 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 9 | deep river
# Processing Record 6 of Set 9 | magadan
# Processing Record 7 of Set 9 | san policarpo
# Processing Record 8 of Set 9 | banda aceh
# Processing Record 9 of Set 9 | taiyuan
# Processing Record 10 of Set 9 | denia
# Processing Record 11 of Set 9 | concarneau
# Processing Record 12 of Set 9 | merauke
# Processing Record 13 of Set 9 | asyut
# Processing Record 14 of Set 9 | turukhansk
# Processing Record 15 of Set 9 | aksay
# Processing Record 16 of Set 9 | copiapo
# Processing Record 17 of Set 9 | bolshiye uki
# City not found. Skipping...
# Processing Record 18 of Set 9 | saint anthony
# Processing Record 19 of Set 9 | kati
# Processing Record 20 of Set 9 | vegueta
# Processing Record 21 of Set 9 | bukachacha
# Processing Record 22 of Set 9 | saldanha
# Processing Record 23 of Set 9 | nemuro
# Processing Record 24 of Set 9 | muyezerskiy
# Processing Record 25 of Set 9 | kailua
# Processing Record 26 of Set 9 | vila velha
# Processing Record 27 of Set 9 | zlocieniec
# Processing Record 28 of Set 9 | sidi qasim
# City not found. Skipping...
# Processing Record 29 of Set 9 | sobolevo
# Processing Record 30 of Set 9 | adre
# Processing Record 31 of Set 9 | mandalgovi
# Processing Record 32 of Set 9 | itacare
# Processing Record 33 of Set 9 | tateyama
# Processing Record 34 of Set 9 | pozo colorado
# Processing Record 35 of Set 9 | snyder
# Processing Record 36 of Set 9 | kuah
# Processing Record 37 of Set 9 | alofi
# Processing Record 38 of Set 9 | fairlie
# Processing Record 39 of Set 9 | lufkin
# Processing Record 40 of Set 9 | portland
# Processing Record 41 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 9 | gushikawa
# Processing Record 43 of Set 9 | wuwei
# Processing Record 44 of Set 9 | mitchell
# Processing Record 45 of Set 9 | vestmannaeyjar
# Processing Record 46 of Set 9 | husavik
# Processing Record 47 of Set 9 | ayan
# Processing Record 48 of Set 9 | diu
# Processing Record 49 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 9 | robertsport
# Processing Record 1 of Set 10 | trujillo
# Processing Record 2 of Set 10 | denpasar
# Processing Record 3 of Set 10 | naze
# Processing Record 4 of Set 10 | takoradi
# Processing Record 5 of Set 10 | polson
# Processing Record 6 of Set 10 | olafsvik
# Processing Record 7 of Set 10 | yangjiang
# Processing Record 8 of Set 10 | uppsala
# Processing Record 9 of Set 10 | nalut
# Processing Record 10 of Set 10 | paracuru
# Processing Record 11 of Set 10 | srednekolymsk
# Processing Record 12 of Set 10 | jasper
# Processing Record 13 of Set 10 | cozumel
# Processing Record 14 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 15 of Set 10 | nantucket
# Processing Record 16 of Set 10 | caravelas
# Processing Record 17 of Set 10 | shache
# Processing Record 18 of Set 10 | tommot
# Processing Record 19 of Set 10 | tumaco
# Processing Record 20 of Set 10 | dixon
# Processing Record 21 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 10 | bithur
# Processing Record 23 of Set 10 | ilovlya
# Processing Record 24 of Set 10 | sokode
# Processing Record 25 of Set 10 | seara
# Processing Record 26 of Set 10 | aklavik
# Processing Record 27 of Set 10 | caucaia
# Processing Record 28 of Set 10 | luderitz
# Processing Record 29 of Set 10 | alawalpur
# Processing Record 30 of Set 10 | bay roberts
# Processing Record 31 of Set 10 | fare
# Processing Record 32 of Set 10 | lukulu
# Processing Record 33 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 10 | mosjoen
# Processing Record 35 of Set 10 | okha
# Processing Record 36 of Set 10 | porto velho
# Processing Record 37 of Set 10 | udachnyy
# Processing Record 38 of Set 10 | salalah
# Processing Record 39 of Set 10 | mahuva
# Processing Record 40 of Set 10 | hollins
# Processing Record 41 of Set 10 | haines junction
# Processing Record 42 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 10 | te anau
# Processing Record 44 of Set 10 | vila
# Processing Record 45 of Set 10 | bojnurd
# Processing Record 46 of Set 10 | karpenision
# City not found. Skipping...
# Processing Record 47 of Set 10 | sulina
# Processing Record 48 of Set 10 | arona
# Processing Record 49 of Set 10 | lar
# Processing Record 50 of Set 10 | tual
# Processing Record 1 of Set 11 | pinos
# Processing Record 2 of Set 11 | maningrida
# Processing Record 3 of Set 11 | warman
# Processing Record 4 of Set 11 | narragansett
# Processing Record 5 of Set 11 | fort nelson
# Processing Record 6 of Set 11 | isangel
# Processing Record 7 of Set 11 | talcahuano
# Processing Record 8 of Set 11 | tongzi
# Processing Record 9 of Set 11 | port talbot
# Processing Record 10 of Set 11 | sao filipe
# Processing Record 11 of Set 11 | birin
# Processing Record 12 of Set 11 | senneterre
# Processing Record 13 of Set 11 | karratha
# Processing Record 14 of Set 11 | san ignacio
# Processing Record 15 of Set 11 | barpali
# Processing Record 16 of Set 11 | coaldale
# Processing Record 17 of Set 11 | richards bay
# Processing Record 18 of Set 11 | kharp
# Processing Record 19 of Set 11 | konstantinovka
# Processing Record 20 of Set 11 | mehran
# Processing Record 21 of Set 11 | maniitsoq
# Processing Record 22 of Set 11 | huarmey
# Processing Record 23 of Set 11 | wagar
# Processing Record 24 of Set 11 | baykit
# Processing Record 25 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 26 of Set 11 | pokhara
# Processing Record 27 of Set 11 | suntar
# Processing Record 28 of Set 11 | jerusalem
# Processing Record 29 of Set 11 | kijang
# Processing Record 30 of Set 11 | cotonou
# Processing Record 31 of Set 11 | trimbak
# Processing Record 32 of Set 11 | mkushi
# Processing Record 33 of Set 11 | akora
# Processing Record 34 of Set 11 | dryden
# Processing Record 35 of Set 11 | ranau
# Processing Record 36 of Set 11 | jackson
# Processing Record 37 of Set 11 | lushunkou
# City not found. Skipping...
# Processing Record 38 of Set 11 | greenville
# Processing Record 39 of Set 11 | inirida
# Processing Record 40 of Set 11 | vanavara
# Processing Record 41 of Set 11 | ossora
# Processing Record 42 of Set 11 | labuhan
# Processing Record 43 of Set 11 | viedma
# Processing Record 44 of Set 11 | amuntai
# Processing Record 45 of Set 11 | miraflores
# Processing Record 46 of Set 11 | lavrentiya
# Processing Record 47 of Set 11 | beloha
# Processing Record 48 of Set 11 | deputatskiy
# Processing Record 49 of Set 11 | ngunguru
# Processing Record 50 of Set 11 | pedra azul
# Processing Record 1 of Set 12 | kungurtug
# Processing Record 2 of Set 12 | latung
# Processing Record 3 of Set 12 | mugur-aksy
# Processing Record 4 of Set 12 | berdigestyakh
# Processing Record 5 of Set 12 | kharan
# Processing Record 6 of Set 12 | grindavik
# Processing Record 7 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 12 | saint-claude
# Processing Record 9 of Set 12 | paraopeba
# Processing Record 10 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 12 | lodja
# Processing Record 12 of Set 12 | ostrovnoy
# Processing Record 13 of Set 12 | sola
# Processing Record 14 of Set 12 | coihaique
# Processing Record 15 of Set 12 | tucuman
# Processing Record 16 of Set 12 | morondava
# Processing Record 17 of Set 12 | redmond
# Processing Record 18 of Set 12 | svetlogorsk
# Processing Record 19 of Set 12 | cap-aux-meules
# Processing Record 20 of Set 12 | khanapur
# Processing Record 21 of Set 12 | saint-pierre
# Processing Record 22 of Set 12 | lephepe
# City not found. Skipping...
# Processing Record 23 of Set 12 | northam
# Processing Record 24 of Set 12 | teguise
# Processing Record 25 of Set 12 | mogadishu
# Processing Record 26 of Set 12 | ambilobe
# Processing Record 27 of Set 12 | tairua
# Processing Record 28 of Set 12 | fuente de oro
# Processing Record 29 of Set 12 | yamada
# Processing Record 30 of Set 12 | angoche
# Processing Record 31 of Set 12 | brokopondo
# Processing Record 32 of Set 12 | shahrud
# Processing Record 33 of Set 12 | senj
# Processing Record 34 of Set 12 | gat
# Processing Record 35 of Set 12 | guerrero negro
# Processing Record 36 of Set 12 | lasa
# Processing Record 37 of Set 12 | kota bahru
# Processing Record 38 of Set 12 | anchorage
# Processing Record 39 of Set 12 | trelew
# Processing Record 40 of Set 12 | oyem
# Processing Record 41 of Set 12 | dagua
# Processing Record 42 of Set 12 | cananea
# Processing Record 43 of Set 12 | mersing
# Processing Record 44 of Set 12 | nata
# Processing Record 45 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 12 | hirara
# Processing Record 47 of Set 12 | lethem
# Processing Record 48 of Set 12 | port hardy
# Processing Record 49 of Set 12 | vanimo
# Processing Record 50 of Set 12 | la ronge
# Processing Record 1 of Set 13 | khorramshahr
# Processing Record 2 of Set 13 | bam
# Processing Record 3 of Set 13 | okahandja
# Processing Record 4 of Set 13 | mahon
# Processing Record 5 of Set 13 | stornoway
# Processing Record 6 of Set 13 | aleksandrov gay
# Processing Record 7 of Set 13 | abu samrah
# Processing Record 8 of Set 13 | paraiso
# Processing Record 9 of Set 13 | kirillov
# Processing Record 10 of Set 13 | mercedes
# Processing Record 11 of Set 13 | alto araguaia
# Processing Record 12 of Set 13 | veydelevka
# Processing Record 13 of Set 13 | toora-khem
# Processing Record 14 of Set 13 | uklana mandi
# Processing Record 15 of Set 13 | nara
# Processing Record 16 of Set 13 | kaimur
# City not found. Skipping...
# Processing Record 17 of Set 13 | rampura
# Processing Record 18 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 13 | maroantsetra
# Processing Record 20 of Set 13 | nigde
# Processing Record 21 of Set 13 | chicama
# Processing Record 22 of Set 13 | santiago
# Processing Record 23 of Set 13 | aksu
# Processing Record 24 of Set 13 | entre rios
# Processing Record 25 of Set 13 | sao luis de montes belos
# Processing Record 26 of Set 13 | marathon
# Processing Record 27 of Set 13 | peterhead
# Processing Record 28 of Set 13 | baracoa
# Processing Record 29 of Set 13 | serpong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp Current Description  Rain (inches)  \
# 0     Busselton -33.65  115.33     73.00     overcast clouds           0.00
# 1        Albany  42.60  -73.97     33.01           clear sky           0.00
# 2         Tiksi  71.69  128.87    -26.97     overcast clouds           0.00
# 3     Saskylakh  71.92  114.08    -34.37          few clouds           0.00
# 4  Puerto Ayora  -0.74  -90.35     73.00          few clouds           0.00
# 5      Oksfjord  70.24   22.35     30.20          light snow           0.00
# 6          Hilo  19.73 -155.09     80.60          light rain           0.13
# 7     Cape Town -33.93   18.42     68.00           clear sky           0.00
# 8       Rikitea -23.12 -134.97     79.11           clear sky           0.00
# 9     Taoudenni  22.68   -3.98     56.03           clear sky           0.00
#
#    Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.00        50         100        8.99      AU
# 1           0.00        76           2        8.01      US
# 2           0.00        86         100        4.61      RU
# 3           0.00        81          16        5.28      RU
# 4           0.00        90          20        6.76      EC
# 5           0.41        73          81       12.75      NO
# 6           0.00        57          90        9.17      US
# 7           0.00        64           0        9.17      ZA
# 8           0.00        65           8        8.10      PF
# 9           0.00        35           0        2.28      ML

# %%
#Check length of cities. 
len(city_data)
# Out:
# 566

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description", "Rain (inches)","Snow (inches)"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.65  115.33     73.00        50         100
# 1        Albany      US  42.60  -73.97     33.01        76           2
# 2         Tiksi      RU  71.69  128.87    -26.97        86         100
# 3     Saskylakh      RU  71.92  114.08    -34.37        81          16
# 4  Puerto Ayora      EC  -0.74  -90.35     73.00        90          20
# 5      Oksfjord      NO  70.24   22.35     30.20        73          81
# 6          Hilo      US  19.73 -155.09     80.60        57          90
# 7     Cape Town      ZA -33.93   18.42     68.00        64           0
# 8       Rikitea      PF -23.12 -134.97     79.11        65           8
# 9     Taoudenni      ML  22.68   -3.98     56.03        35           0
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        8.99     overcast clouds           0.00           0.00
# 1        8.01           clear sky           0.00           0.00
# 2        4.61     overcast clouds           0.00           0.00
# 3        5.28          few clouds           0.00           0.00
# 4        6.76          few clouds           0.00           0.00
# 5       12.75          light snow           0.00           0.41
# 6        9.17          light rain           0.13           0.00
# 7        9.17           clear sky           0.00           0.00
# 8        8.10           clear sky           0.00           0.00
# 9        2.28           clear sky           0.00           0.00

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# Rain (inches)          float64
# Snow (inches)          float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)']>0]
raining_cities
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 6            Hilo      US  19.73 -155.09     80.60        57          90
# 10          Vaini      TO -21.20 -175.20     80.60        88          75
# 18     Hambantota      LK   6.12   81.12     75.20       100          75
# 27          Gamba      GA  -2.65   10.00     76.41        91         100
# 31       Bengkulu      ID  -3.80  102.27     82.20        72          28
# ..            ...     ...    ...     ...       ...       ...         ...
# 535        Lethem      GY   3.38  -59.80     78.80        73           5
# 536    Port Hardy      CA  50.70 -127.42     42.80        81          90
# 537        Vanimo      PG  -2.67  141.30     87.69        64          52
# 541     Okahandja      NA -21.98   16.92     63.00       100         100
# 555  Maroantsetra      MG -15.43   49.73     75.76        82          29
#
#      Wind Speed          Current Description  Rain (inches)  Snow (inches)
# 6          9.17                   light rain         0.1300            0.0
# 10        11.41                   light rain         0.7400            0.0
# 18         4.70                moderate rain         3.0300            0.0
# 27         2.04                   light rain         0.3400            0.0
# 31         1.88                   light rain         0.7070            0.0
# ..          ...                          ...            ...            ...
# 535       13.78                moderate rain         2.2556            0.0
# 536        8.05  light intensity shower rain         0.1300            0.0
# 537        3.20                   light rain         0.5800            0.0
# 541        3.36                   light rain         0.1400            0.0
# 555        7.18                   light rain         0.5600            0.0
#
# [71 rows x 11 columns]

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)']>0]
snowing_cities
# Out:
#                    City Country    Lat     Lng  Max Temp  Humidity  \
# 5              Oksfjord      NO  70.24   22.35     30.20        73
# 46             Bogatoye      RU  53.06   51.33     19.67        98
# 55         Beringovskiy      RU  63.05  179.32     14.85        96
# 87               Narsaq      GL  60.92  -46.05     30.20        80
# 93             Tasiilaq      GL  65.61  -37.64     30.20        86
# 146             Paamiut      GL  61.99  -49.67     28.49        98
# 152           Athabasca      CA  54.72 -113.29     28.40        74
# 161            Qaqortoq      GL  60.72  -46.03     30.20        80
# 168          Antigonish      CA  45.62  -62.00     32.00        97
# 183     Port Hawkesbury      CA  45.62  -61.35     32.00        96
# 216                 Ola      RU  59.58  151.28     -4.25        89
# 224            Radeberg      DE  51.12   13.92     35.01        97
# 236              Tromso      NO  69.65   18.96     33.80        95
# 263            Thompson      CA  55.74  -97.86     10.40        85
# 274            Itoigawa      JP  37.03  137.85     33.01        86
# 350  Havre-Saint-Pierre      CA  50.23  -63.60     14.00        78
# 367          Turukhansk      RU  65.82   87.98    -17.05        88
# 382          Mandalgovi      MN  45.76  106.27    -12.44        86
# 465           Maniitsoq      GL  65.42  -52.90     22.87        97
# 509      Cap-Aux-Meules      CA  47.38  -61.86     30.20       100
# 525                Lasa      IT  46.62   10.70     33.01       100
# 547            Kirillov      RU  59.86   38.38     27.88        99
# 563           Peterhead      GB  57.51   -1.80     36.00        93
#
#      Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 5            81       12.75          light snow            0.0         0.4100
# 46          100       11.16          light snow            0.0         0.3200
# 55          100       25.32                snow            0.0         0.6000
# 87           95        1.12   light shower snow            0.0         0.3700
# 93          100       32.21                snow            0.0         1.9100
# 146         100       12.68                snow            0.0         0.5100
# 152         100        4.70          light snow            0.0         0.1500
# 161          85        1.12   light shower snow            0.0         0.2100
# 168         100        3.00                snow            0.0         1.3300
# 183          90       21.92                snow            0.0         1.5400
# 216         100       15.12          light snow            0.0         0.1500
# 224          90       11.41                snow            0.0         1.6200
# 236          75        8.05   light shower snow            0.0         0.1700
# 263          90        5.82          light snow            0.0         0.3800
# 274         100        7.61          light snow            0.0         0.4600
# 350          75        8.05       broken clouds            0.0         0.1000
# 367         100        9.24          light snow            0.0         0.1600
# 382          37        9.71          light snow            0.0         0.1608
# 465         100       10.98          light snow            0.0         0.3400
# 509         100       20.80          light snow            0.0         0.3400
# 525          90        3.38                snow            0.0         0.6600
# 547         100        4.07                snow            0.0         0.5620
# 563          66        9.17                snow            0.0         0.8200

# %%
# Create the output File (CSV)
output_data_file = "data/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
